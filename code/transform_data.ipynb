# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.linear_model import LinearRegression


# import csv data 
Biz_df = pd.read_csv("data/BusinessAnalyst.csv") 
Biz_df.head()
# Out:
#   Unnamed: 0 index                                         Job Title  \
# 0          0     0  Business Analyst - Clinical & Logistics Platform
# 1          1     1                                  Business Analyst
# 2          2     2                                      Data Analyst
# 3          3     3   Information Security Analyst, Incident Response
# 4          4     4                     Analyst - FP&A Global Revenue
#
#                Salary Estimate  \
# 0  $56K-$102K (Glassdoor est.)
# 1  $56K-$102K (Glassdoor est.)
# 2  $56K-$102K (Glassdoor est.)
# 3  $56K-$102K (Glassdoor est.)
# 4  $56K-$102K (Glassdoor est.)
#
#                                      Job Description Rating  \
# 0  Company Overview\n\n\nAt Memorial Sloan Ketter...    3.9
# 1  We are seeking for an energetic and collaborat...    3.8
# 2  For more than a decade, Asembia has been worki...    3.6
# 3  Job Description Summary\nThe Information Secur...    3.6
# 4  Magnite is the world's largest independent sel...    3.4
#
#                     Company Name            Location        Headquarters  \
# 0  Memorial Sloan-Kettering\n3.9        New York, NY        New York, NY
# 1   Paine Schwartz Partners\n3.8        New York, NY        New York, NY
# 2                   Asembia\n3.6    Florham Park, NJ    Florham Park, NJ
# 3                        BD\n3.6  Franklin Lakes, NJ  Franklin Lakes, NJ
# 4           Rubicon Project\n3.4        New York, NY     Los Angeles, CA
#
#                     Size Founded       Type of ownership  \
# 0       10000+ employees    1884  Nonprofit Organization
# 1      1 to 50 employees      -1       Company - Private
# 2  501 to 1000 employees    2004       Company - Private
# 3       10000+ employees    1897        Company - Public
# 4   201 to 500 employees    2007        Company - Public
#
#                              Industry                     Sector  \
# 0    Health Care Services & Hospitals                Health Care
# 1    Venture Capital & Private Equity                    Finance
# 2           Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 3  Health Care Products Manufacturing              Manufacturing
# 4                            Internet     Information Technology
#
#                       Revenue  \
# 0      $2 to $5 billion (USD)
# 1    Unknown / Non-Applicable
# 2     $5 to $10 million (USD)
# 3          $10+ billion (USD)
# 4  $100 to $500 million (USD)
#
#                                          Competitors Easy Apply
# 0  Mayo Clinic, The Johns Hopkins Hospital, MD An...         -1
# 1                                                 -1       True
# 2                                                 -1         -1
# 3                            Abbott, Siemens, Baxter         -1
# 4                 PubMatic, AppNexus, Index Exchange       True

# %%
# check for null values
Biz_df.isnull()

# data info
Biz_df.info()

# get descriptive statistics
Biz_df.describe()

# get the number of row and columns 
Biz_df.shape

# check the columns 
Biz_df.columns

# drop null values
Biz_df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4092 entries, 0 to 4091
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4092 non-null   object
#  1   index              4092 non-null   object
#  2   Job Title          4092 non-null   object
#  3   Salary Estimate    4092 non-null   object
#  4   Job Description    4092 non-null   object
#  5   Rating             4092 non-null   object
#  6   Company Name       4092 non-null   object
#  7   Location           4092 non-null   object
#  8   Headquarters       4092 non-null   object
#  9   Size               4092 non-null   object
#  10  Founded            4092 non-null   object
#  11  Type of ownership  4092 non-null   object
#  12  Industry           4092 non-null   object
#  13  Sector             4092 non-null   object
#  14  Revenue            4092 non-null   object
#  15  Competitors        3692 non-null   object
#  16  Easy Apply         3692 non-null   object
# dtypes: object(17)
# memory usage: 543.6+ KB
#      Unnamed: 0 index                                         Job Title  \
# 0             0     0  Business Analyst - Clinical & Logistics Platform
# 1             1     1                                  Business Analyst
# 2             2     2                                      Data Analyst
# 3             3     3   Information Security Analyst, Incident Response
# 4             4     4                     Analyst - FP&A Global Revenue
# ...         ...   ...                                               ...
# 3687       3687  4395                             Pega Business Analyst
# 3688       3688  4396                               Jr.Business Analyst
# 3689       3689  4397   Business Process Analyst/Remote 4 mth+ contract
# 3690       3690  4398                              AVP, Business System
# 3691       3691  4399     DPS - LS - Cyber Risk & Vulnerability Analyst
#
#                   Salary Estimate  \
# 0     $56K-$102K (Glassdoor est.)
# 1     $56K-$102K (Glassdoor est.)
# 2     $56K-$102K (Glassdoor est.)
# 3     $56K-$102K (Glassdoor est.)
# 4     $56K-$102K (Glassdoor est.)
# ...                           ...
# 3687  $58K-$103K (Glassdoor est.)
# 3688  $58K-$103K (Glassdoor est.)
# 3689  $58K-$103K (Glassdoor est.)
# 3690  $58K-$103K (Glassdoor est.)
# 3691  $58K-$103K (Glassdoor est.)
#
#                                         Job Description Rating  \
# 0     Company Overview\n\n\nAt Memorial Sloan Ketter...    3.9
# 1     We are seeking for an energetic and collaborat...    3.8
# 2     For more than a decade, Asembia has been worki...    3.6
# 3     Job Description Summary\nThe Information Secur...    3.6
# 4     Magnite is the world's largest independent sel...    3.4
# ...                                                 ...    ...
# 3687  • 5 yrs relevant experience in:- Experience wi...    3.1
# 3688  Job Description\n\nNew businesses are making t...    5.0
# 3689  Title: Business Process Analyst\nDuration: 4+ ...   -1.0
# 3690  We are looking for a AVP Business System Analy...    3.5
# 3691  DPS - LS - Cyber Risk & Vulnerability Analyst ...    3.4
#
#                                        Company Name            Location  \
# 0                     Memorial Sloan-Kettering\n3.9        New York, NY
# 1                      Paine Schwartz Partners\n3.8        New York, NY
# 2                                      Asembia\n3.6    Florham Park, NJ
# 3                                           BD\n3.6  Franklin Lakes, NJ
# 4                              Rubicon Project\n3.4        New York, NY
# ...                                             ...                 ...
# 3687  Tista Science and Technology Corporation\n3.1          Austin, TX
# 3688          Staffigo Technical Services, LLC\n5.0          Austin, TX
# 3689                        Suncap Technology, Inc.          Austin, TX
# 3690                             LPL Financial\n3.5          Austin, TX
# 3691         TEXAS DEPARTMENT OF PUBLIC SAFETY\n3.4          Austin, TX
#
#             Headquarters                    Size Founded  \
# 0           New York, NY        10000+ employees    1884
# 1           New York, NY       1 to 50 employees      -1
# 2       Florham Park, NJ   501 to 1000 employees    2004
# 3     Franklin Lakes, NJ        10000+ employees    1897
# 4        Los Angeles, CA    201 to 500 employees    2007
# ...                  ...                     ...     ...
# 3687       Rockville, MD   501 to 1000 employees    2005
# 3688       Woodridge, IL     51 to 200 employees    2008
# 3689                  -1                      -1      -1
# 3690          Boston, MA  1001 to 5000 employees    1968
# 3691          Austin, TX  1001 to 5000 employees      -1
#
#            Type of ownership                               Industry  \
# 0     Nonprofit Organization       Health Care Services & Hospitals
# 1          Company - Private       Venture Capital & Private Equity
# 2          Company - Private              Biotech & Pharmaceuticals
# 3           Company - Public     Health Care Products Manufacturing
# 4           Company - Public                               Internet
# ...                      ...                                    ...
# 3687       Company - Private                             Consulting
# 3688       Company - Private                            IT Services
# 3689                      -1                                     -1
# 3690        Company - Public  Investment Banking & Asset Management
# 3691              Government                  Municipal Governments
#
#                          Sector                     Revenue  \
# 0                   Health Care      $2 to $5 billion (USD)
# 1                       Finance    Unknown / Non-Applicable
# 2     Biotech & Pharmaceuticals     $5 to $10 million (USD)
# 3                 Manufacturing          $10+ billion (USD)
# 4        Information Technology  $100 to $500 million (USD)
# ...                         ...                         ...
# 3687          Business Services     $5 to $10 million (USD)
# 3688     Information Technology   $50 to $100 million (USD)
# 3689                         -1                          -1
# 3690                    Finance      $2 to $5 billion (USD)
# 3691                 Government    Unknown / Non-Applicable
#
#                                             Competitors Easy Apply
# 0     Mayo Clinic, The Johns Hopkins Hospital, MD An...         -1
# 1                                                    -1       True
# 2                                                    -1         -1
# 3                               Abbott, Siemens, Baxter         -1
# 4                    PubMatic, AppNexus, Index Exchange       True
# ...                                                 ...        ...
# 3687                                                 -1         -1
# 3688                                                 -1         -1
# 3689                                                 -1         -1
# 3690          Fidelity Investments, UBS, Morgan Stanley         -1
# 3691                                                 -1         -1
#
# [3692 rows x 17 columns]

# %%
# Split salary into two columns min salary and max salary.
Biz_df['Min_Salary'], Biz_df['Max_Salary']= Biz_df['Salary Estimate'].str.split('-').str
Biz_df['Max_Salary'] = Biz_df['Max_Salary'].str.replace(r'\(Glassdoor est.\)','', regex= True)
Biz_df['Max_Salary'] = Biz_df['Max_Salary'].str.replace(r'\(Employer est.\)','', regex= True)
Biz_df['Min_Salary'] = Biz_df['Min_Salary'].str.replace('$','')
Biz_df['Max_Salary'] = Biz_df['Max_Salary'].str.replace('$','')
# turning min_salary, max_salary and avg_salary to thousands
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0

Biz_df['Min_Salary'] = Biz_df['Min_Salary'].apply(value_to_float)
Biz_df['Max_Salary'] = Biz_df['Max_Salary'].apply(value_to_float)


# Cleaning and replacing some characters and numerics 
Biz_df['Avg_Salary'] = Biz_df['Salary Estimate'].str.replace(r'\(Glassdoor est.\)','', regex= True)
Biz_df['Avg_Salary'] = Biz_df['Avg_Salary'].str.replace(r'\(Employer est.\)','', regex= True)
Biz_df['Avg_Salary'] = Biz_df['Avg_Salary'].str.replace('$','')
Biz_df['Avg_Salary'] = Biz_df['Avg_Salary'].str.replace('K','')

# split the numbers in order to get the average 
Biz_df['Avg_Salary'].str.split('-')
Biz_df['Avg_Salary']= Biz_df['Avg_Salary'].str.split('-')
Biz_df['Avg_Salary'] = Biz_df[['Max_Salary','Min_Salary']].mean(axis=1)
Biz_df['Avg_Salary'] = Biz_df['Avg_Salary'].astype(float)


# cleaning company name column 
Biz_df['Company Name'] = Biz_df['Company Name'].str.replace('\d+', '', regex=True)
Biz_df['Company Name']= Biz_df['Company Name'].str.replace('\n.', '', regex= True)


# Replace all the -1 or -1.0 or '-1' to NaN in all columns 
Biz_df['Easy Apply'] = Biz_df['Easy Apply'].replace('True',1)
Biz_df['Easy Apply'] = Biz_df['Easy Apply'].replace('-1',0)
Biz_df = Biz_df.replace(-1,0)
Biz_d = Biz_df.replace('-1.0',0)
Biz_df = Biz_df.replace('-1',0) 

# check for values in rating and clean rating column
Biz_df['Rating'].value_counts(ascending=True) 

rating_clean = ['-1.0','Jacksonville, FL','Orange Park, FL','Jacksonville Beach, FL',
            'Mayport, FL', 'Ponte Vedra Beach, FL', 'Fleming Island, FL']

def clean_rating(x):
    if x in rating_clean:
        return np.nan
    else:
        return x 

Biz_df['Rating'] = Biz_df['Rating'].apply(clean_rating) 
Biz_df['Rating'] = Biz_df['Rating'].astype(float)


# check for values in Founded and clean founded column 
Biz_df['Founded'].value_counts(ascending=True) 

founded_clean = ['Accounting', 'Advertising & Marketing', 'Aerospace & Defense', 'Architectural & Engineering Services', 'Banks & Credit Unions', 
'Biotech & Pharmaceuticals', 'Building & Personnel Services', 'Colleges & Universities', 'Computer Hardware & Software', 'Consulting', 
'Department, Clothing, & Shoe Stores', 'Education Training Services', 'Energy', 'Enterprise Software & Network Solutions', 'Federal Agencies',
'Financial Transaction Processing', 'Health Care Products Manufacturing', 'Health Care Services & Hospitals', 'Home Centers & Hardware Stores', 
'Insurance Carriers', 'Real Estate', 'Religious Organizations', 'Shipping', 'Sports & Recreation', 'Staffing & Outsourcing', 'Telecommunications Services', 
'Timber Operations', 'Investment Banking & Asset Management', 'IT Services', 'Lending', 'Logistics & Supply Chain', 'Moving Services', 'Rail',
'Transportation Management', 'Vehicle Dealers', 'Wholesale' ]

def clean_founded(x):
    if x in founded_clean:
        return np.nan
    else:
        return x 

Biz_df['Founded'] = Biz_df['Founded'].apply(clean_founded) 
Biz_df['Founded'] = Biz_df['Founded'].astype(float)

# check for values in company and clean company column
Biz_df['Company Name'].value_counts(ascending=True) 

company_clean = ['Jacksonville, FL','New York, NY','Woodridge, IL','- ','Chicago, IL', 'Burbank, CA', 'Somerset, NJ','San Diego, CA', 'Mount Laurel, NJ',
            'Atlanta, GA', 'Tampa, FL', 'Coral Springs, FL', 'Gainesville, FL', 'Menlo Park, CA', 'London, United Kingdom', 'Houston, TX', ]

def clean_rating(x):
    if x in company_clean:
        return np.nan
    else:
        return x 

Biz_df['Company Name'] = Biz_df['Company Name'].apply(clean_rating) 
Biz_df['Company Name'].astype(str)

# clean revenue column 
Biz_df['Revenue']= Biz_df['Revenue'].str.replace(r'\((USD)\)','', regex= True)
Biz_df['Revenue']= Biz_df['Revenue'].str.replace('Less than','')
Biz_df['Revenue']= Biz_df['Revenue'].str.replace('$','')
Biz_df['Revenue']= Biz_df['Revenue'].str.replace('billion','')
Biz_df['Revenue']= Biz_df['Revenue'].str.replace('million','')
Biz_df['Revenue']= Biz_df['Revenue'].str.replace('+','')
Biz_df['Revenue']= Biz_df['Revenue'].str.replace('to','')
Biz_df['Revenue']= Biz_df['Revenue'].replace('Unknown / Non-Applicable',np.nan)

# Spliting location into city and state and fixing state column 
Biz_df[['City','State']] = Biz_df['Location'].str.split(', ',expand=True).drop([2],axis=1)
Biz_df['State'] = Biz_df['State'].str.replace('Los Angeles','CA')
# split Headquater 
Biz_df['HQ City'],Biz_df['Headquarter'] = Biz_df['Headquarters'].str.split(', ',1).str

#add column that contains Job_id
Biz_df = Biz_df.assign(Job_id=range(len(Biz_df)))
job_id = Biz_df.pop('Job_id')
Biz_df.insert(0, 'Job_id', job_id)

#add column that contains company_id
Biz_df = Biz_df.assign(Company_id=range(len(Biz_df)))
company_id = Biz_df.pop('Company_id')
Biz_df.insert(7, 'Company_id', company_id)

#add column that contains state_id
Biz_df = Biz_df.assign(State_id=range(len(Biz_df)))
state_id = Biz_df.pop('State_id')
Biz_df.insert(22, 'State_id', state_id)

# drop the 0 in the sector column 
Biz_df.drop(Biz_df[Biz_df['Sector'] == 0].index, inplace = True)

#droping all NaN values
Biz_df.dropna(inplace=True)


Biz_df.head()
# Out:
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   Biz_df['Min_Salary'], Biz_df['Max_Salary']= Biz_df['Salary Estimate'].str.split('-').str
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Biz_df['Min_Salary'] = Biz_df['Min_Salary'].str.replace('$','')
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Biz_df['Max_Salary'] = Biz_df['Max_Salary'].str.replace('$','')
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Biz_df['Avg_Salary'] = Biz_df['Avg_Salary'].str.replace('$','')
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:99: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Biz_df['Revenue']= Biz_df['Revenue'].str.replace('$','')
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:102: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Biz_df['Revenue']= Biz_df['Revenue'].str.replace('+','')
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:110: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   Biz_df['HQ City'],Biz_df['Headquarter'] = Biz_df['Headquarters'].str.split(', ',1).str
# /var/folders/x7/crx4vr4x15bb27ylnzvk1p_r0000gn/T/ipykernel_43016/2698869402.py:110: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   Biz_df['HQ City'],Biz_df['Headquarter'] = Biz_df['Headquarters'].str.split(', ',1).str
#    Job_id Unnamed: 0 index                                         Job Title  \
# 0       0          0     0  Business Analyst - Clinical & Logistics Platform
# 2       2          2     2                                      Data Analyst
# 3       3          3     3   Information Security Analyst, Incident Response
# 4       4          4     4                     Analyst - FP&A Global Revenue
# 6       6          6     6                     Investment Analyst - Graduate
#
#                Salary Estimate  \
# 0  $56K-$102K (Glassdoor est.)
# 2  $56K-$102K (Glassdoor est.)
# 3  $56K-$102K (Glassdoor est.)
# 4  $56K-$102K (Glassdoor est.)
# 6  $56K-$102K (Glassdoor est.)
#
#                                      Job Description  Rating  Company_id  \
# 0  Company Overview\n\n\nAt Memorial Sloan Ketter...     3.9           0
# 2  For more than a decade, Asembia has been worki...     3.6           2
# 3  Job Description Summary\nThe Information Secur...     3.6           3
# 4  Magnite is the world's largest independent sel...     3.4           4
# 6  About Swiss Re\n\nThe Swiss Re Group is one of...     3.8           6
#
#                Company Name            Location  ...  \
# 0  Memorial Sloan-Kettering        New York, NY  ...
# 2                   Asembia    Florham Park, NJ  ...
# 3                        BD  Franklin Lakes, NJ  ...
# 4           Rubicon Project        New York, NY  ...
# 6                  Swiss Re        New York, NY  ...
#
#                                          Competitors Easy Apply  Min_Salary  \
# 0  Mayo Clinic, The Johns Hopkins Hospital, MD An...        0.0     56000.0
# 2                                                  0        0.0     56000.0
# 3                            Abbott, Siemens, Baxter        0.0     56000.0
# 4                 PubMatic, AppNexus, Index Exchange        1.0     56000.0
# 6                       Munich Re, Hannover RE, SCOR        0.0     56000.0
#
#   Max_Salary Avg_Salary State_id            City State         HQ City  \
# 0   102000.0    79000.0        0        New York    NY        New York
# 2   102000.0    79000.0        2    Florham Park    NJ    Florham Park
# 3   102000.0    79000.0        3  Franklin Lakes    NJ  Franklin Lakes
# 4   102000.0    79000.0        4        New York    NY     Los Angeles
# 6   102000.0    79000.0        6        New York    NY          Zurich
#
#    Headquarter
# 0           NY
# 2           NJ
# 3           NJ
# 4           CA
# 6  Switzerland
#
# [5 rows x 27 columns]

# %%
# Split the revenue column and get the average revenue 
Biz_df['Revenue']= Biz_df['Revenue'].str.split()
def rev_average(x):
    num = 0
    for r in x:
        num = float(num) + float(r)        

    avg = num / len(x) 
    return avg

Biz_df['Revenue'] = Biz_df['Revenue'].apply(rev_average)

# %%
# converting the aveage revenue into Millions and Billions USD
def value_to_float(x):
    lst = [3, 17.5, 300, 37.5, 7.5, 75, 250.5, 1]
    if x in lst:
        return x * 1000000
    else:
        return x * 1000000000
Biz_df['Revenue'] = Biz_df['Revenue'].apply(value_to_float)

# %%
Biz_df_clean = Biz_df.drop(labels=["Unnamed: 0", "index","Salary Estimate", "Job Description", "Location", "Headquarters", "Competitors", "HQ City"], axis=1)
Biz_df_clean.columns = ['Job_id', "Job Title", "Rating", 'Company_id', "Company Name", "Size", "Founded", "Type of ownership", "Industry", 'Sector', "Revenue", "Easy Apply","Min_Salary", "Max_Salary", "Avg_Salary", 'State_id', "City", "State", "Headquarter"]
Biz_df_clean.head()
# Out:
#    Job_id                                         Job Title  Rating  \
# 0       0  Business Analyst - Clinical & Logistics Platform     3.9
# 2       2                                      Data Analyst     3.6
# 3       3   Information Security Analyst, Incident Response     3.6
# 4       4                     Analyst - FP&A Global Revenue     3.4
# 6       6                     Investment Analyst - Graduate     3.8
#
#    Company_id              Company Name                   Size  Founded  \
# 0           0  Memorial Sloan-Kettering       10000+ employees   1884.0
# 2           2                   Asembia  501 to 1000 employees   2004.0
# 3           3                        BD       10000+ employees   1897.0
# 4           4           Rubicon Project   201 to 500 employees   2007.0
# 6           6                  Swiss Re       10000+ employees   1863.0
#
#         Type of ownership                            Industry  \
# 0  Nonprofit Organization    Health Care Services & Hospitals
# 2       Company - Private           Biotech & Pharmaceuticals
# 3        Company - Public  Health Care Products Manufacturing
# 4        Company - Public                            Internet
# 6        Company - Public     Insurance Agencies & Brokerages
#
#                       Sector       Revenue  Easy Apply  Min_Salary  \
# 0                Health Care  3.500000e+09         0.0     56000.0
# 2  Biotech & Pharmaceuticals  7.500000e+06         0.0     56000.0
# 3              Manufacturing  1.000000e+10         0.0     56000.0
# 4     Information Technology  3.000000e+08         1.0     56000.0
# 6                  Insurance  1.000000e+10         0.0     56000.0
#
#    Max_Salary  Avg_Salary  State_id            City State  Headquarter
# 0    102000.0     79000.0         0        New York    NY           NY
# 2    102000.0     79000.0         2    Florham Park    NJ           NJ
# 3    102000.0     79000.0         3  Franklin Lakes    NJ           NJ
# 4    102000.0     79000.0         4        New York    NY           CA
# 6    102000.0     79000.0         6        New York    NY  Switzerland

# %%
# Convert clean data into csv file
Biz_df_clean.to_csv('data/clean_data.csv', index = False)

# %%
df= pd.read_csv("data/clean_data.csv") 
state_df= df[["State_id","City", "State"]]
state_df.to_csv('data/state.csv',index = False)

company_df = df[['Company_id', "State_id", "Company Name", "Rating", "Size", "Founded", "Type of ownership", "Industry", 'Sector', "Revenue", "Headquarter"]]
company_df.to_csv('data/company.csv', index = False) 

job_df = df[['Job_id', "Job Title", "Easy Apply", "Avg_Salary","Min_Salary", "Max_Salary", "Company_id", "State_id"]]
job_df.to_csv('data/job.csv', index= False)
