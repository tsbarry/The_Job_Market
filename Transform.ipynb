# %% [markdown]
# We Import our Data

# %%
import pandas as pd

#Importing Data

Biz_DF = pd.read_csv("Raw_Data/BusinessAnalyst.csv")
Biz_DF.head()
# Out:
#   Unnamed: 0 index                                         Job Title  \
# 0          0     0  Business Analyst - Clinical & Logistics Platform
# 1          1     1                                  Business Analyst
# 2          2     2                                      Data Analyst
# 3          3     3   Information Security Analyst, Incident Response
# 4          4     4                     Analyst - FP&A Global Revenue
#
#                Salary Estimate  \
# 0  $56K-$102K (Glassdoor est.)
# 1  $56K-$102K (Glassdoor est.)
# 2  $56K-$102K (Glassdoor est.)
# 3  $56K-$102K (Glassdoor est.)
# 4  $56K-$102K (Glassdoor est.)
#
#                                      Job Description Rating  \
# 0  Company Overview\n\n\nAt Memorial Sloan Ketter...    3.9
# 1  We are seeking for an energetic and collaborat...    3.8
# 2  For more than a decade, Asembia has been worki...    3.6
# 3  Job Description Summary\nThe Information Secur...    3.6
# ...

# %% [markdown]
# Next we Explore how many missing values present.

# %%
#Checking Data Values

Biz_DF["Job Title"].isna()
print (Biz_DF["Job Title"].isna())

Biz_DF["Job Title"].isna().count()
print (Biz_DF["Job Title"].isna().count())

Biz_DF["Job Title"].isna().sum()
print (Biz_DF["Job Title"].isna().sum())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4087    False
# 4088    False
# 4089    False
# 4090    False
# 4091    False
# Name: Job Title, Length: 4092, dtype: bool
# 4092
# 0

# %% [markdown]
# Lets find Null Values to help determine which columns to drop.

# %%
null_counts = Biz_DF.groupby('Job Title')

null_counts = Biz_DF.isnull().sum(axis=1)
null_counts_by_category = null_counts.groupby(Biz_DF['Category']).sum()
print(null_counts)

# %%
Biz_DF["Job Title"] = Biz_DF["Job Title"].fillna(value = False)
print (Biz_DF["Job Title"])

Biz_DF["Job Title"].isna()
print (Biz_DF["Job Title"].isna())

Biz_DF["Job Title"].isna().count()
print (Biz_DF["Job Title"].isna().count())

Biz_DF["Job Title"].isna().sum()
print (Biz_DF["Job Title"].isna().sum())
# Out:
# 0        Business Analyst - Clinical & Logistics Platform
# 1                                        Business Analyst
# 2                                            Data Analyst
# 3         Information Security Analyst, Incident Response
# 4                           Analyst - FP&A Global Revenue
#                               ...
# 4087    Ref ID: 01120-0011488945Classification: Help D...
# 4088    Job Title: System Analyst (Data) - PL/SQl Serv...
# 4089    Job Opening Summary\nReports to the Systems Ap...
# 4090    Job Description\nA knowledgeable job-seeker is...
# 4091    Job Summary\n\nThis unique analyst position re...
# Name: Job Title, Length: 4092, dtype: object
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4087    False
# 4088    False
# 4089    False
# 4090    False
# 4091    False
# Name: Job Title, Length: 4092, dtype: bool
# 4092
# 0

# %% [markdown]
# After this we explore how many unique Job Titles exist in our data and order them by quantity in descending order. We will be dealing with only the top 25 titles.

# %%
Biz_DF['Job Title'].nunique()
Job_Title_Counts = Biz_DF['Job Title'].value_counts(ascending=False).head(25)

Job_Title_Counts
# Out:
# Business Analyst                   502
# Data Analyst                       145
# Business Systems Analyst           118
# Senior Business Analyst             68
# Business Intelligence Analyst       50
# Technical Business Analyst          36
# Sr. Business Analyst                32
# Business System Analyst             30
# IT Business Analyst                 30
# Financial Analyst                   25
# Systems Analyst                     25
# Management Analyst                  21
# Business Analyst III                21
# Project Analyst                     21
# Salesforce Business Analyst         19
# Senior Business Systems Analyst     18
# Business Process Analyst            17
# Entry Level Business Analyst        17
# Business Analyst II                 15
# Product Analyst                     13
# Business Data Analyst               13
# System Analyst                      11
# Business Analyst Level-1            10
# Jr. Business Analyst                10
# ...

# %% [markdown]
# Considering there are mixed values and strings we will clean our salaries column in preperation for calculating the average salary for each Job Title catagory.

# %%
Biz_DF['Salary Estimate'] = Biz_DF['Salary Estimate'].str.replace('(Glassdoor est.)',(''))
Biz_DF['Salary Estimate']

Job_Title_Counts = Biz_DF[['Job Title', 'Salary Estimate']].value_counts(ascending=False).head(25)

Job_Title_Counts
# Out:
# /var/folders/f_/v4jjg_gj1_q01bz6mqdkdc_80000gp/T/ipykernel_51058/2513060140.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Biz_DF['Salary Estimate'] = Biz_DF['Salary Estimate'].str.replace('(Glassdoor est.)',(''))
# Job Title                 Salary Estimate
# Business Analyst          $48K-$92K ()       23
#                           $45K-$82K ()       22
#                           $81K-$159K ()      21
#                           $85K-$135K ()      21
#                           $74K-$85K ()       20
#                           $55K-$78K ()       20
#                           $62K-$120K ()      17
#                           $59K-$85K ()       17
#                           $48K-$87K ()       14
#                           $69K-$131K ()      13
#                           $32K-$61K ()       13
#                           $99K-$118K ()      13
#                           $62K-$79K ()       12
# ...

# %% [markdown]
# THIS IS WHERE I TAKE A BREAK. EVERYTHING BELOW THIS POINT IN UNREFINED CODE WHICH CONTAIND ERRORS.

# %% [markdown]
# The code below is to transform any string data in the salary estimate column into an intiger

# %%
Biz_DF['Salary Estimate'] = Biz_DF['Salary Estimate'].str.replace('(Glassdoor est.)',('')).str.split('-', expand=True).astype(float).mean(axis=1)

Job_Title_Means = Biz_DF.groupby('Job Title')['Salary Estimate'].mean().reset_index()
print(Job_Title_Means)

# %% [markdown]
# Attempt to transform all numerics values in string format into integers

# %%
Biz_DF = Biz_DF.applymap(lambda x: int(x) if str(x).isnumeric() else x)
Biz_DF
# Out:
#                                              Unnamed: 0  \
# 0                                                     0
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 4087                                  Help Desk Analyst
# 4088              System Analyst (Data) - PL/SQl Server
# 4089  Programmer Analyst- PeopleSoft ( Finance and S...
# 4090                            Loss Mitigation Analyst
# 4091                     Financial Analyst II - Baptist
#
#                             index  \
# 0                               0
# 1                               1
# 2                               2
# 3                               3
# 4                               4
# ...                           ...
# 4087  $66K-$114K (Glassdoor est.)
# ...

# %%
Job_Title_Counts = Biz_DF[['Job Title', 'Salary Estimate']].mean()
# Out:
# /var/folders/f_/v4jjg_gj1_q01bz6mqdkdc_80000gp/T/ipykernel_51058/4036323811.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Job_Title_Counts = Biz_DF[['Job Title', 'Salary Estimate']].mean()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from ast import literal_eval

Biz_DF["Job Title"].isna().sum()

droped_df = Biz_DF.dropna(subset = ["sJob_Title_Counts"])
droped_df.isna().sum()
droped_df

mlb = MultiLabelBinarizer()
def convert_to_list(s):
    try:
        return eval(s)
    except:
        return []
Biz_DF['description_tokens'] = Biz_DF['description_tokens'].apply(convert_to_list)

mlb = MultiLabelBinarizer()
mlb.fit(Biz_DF['description_tokens'])

FTokens = pd.DataFrame(mlb.transform(Biz_DF['description_tokens']), columns=mlb.classes_)
Biz_DF = pd.concat([Biz_DF, FTokens], axis=1)
